# %%
import mysql.connector 
import pandas as pd 
import matplotlib.pyplot as plt 
def fun01(): 
    cnx = mysql.connector.connect(user='root', 
    password='Student123@', 
    host='localhost', 
    database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
    "FROM STUDENT S, ENROLMENT E " 
                                "WHERE S.STUDENTID=E.STUDENTID ",  cnx) 
    print(results) 
    cnx.close()       
fun01()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 6       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 7        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 8   KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# 9    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 10    JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# ...

# %%
def fun02(): 
    cnx = mysql.connector.connect(user='root', 
                              password='Student123@', 
                              host='localhost', 
                              database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
                                "FROM STUDENT S NATURAL JOIN ENROLMENT E ",  cnx) 
    print(results) 
    cnx.close()       
fun02()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 6     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 7     JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# 8       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 9        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 10  KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# ...

# %%
import mysql.connector 
import pandas as pd 
import matplotlib.pyplot as plt 
def fun03(): 
    cnx = mysql.connector.connect(user='root', 
                              password='Student123@', 
                              host='localhost', 
                              database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
                                "FROM STUDENT S JOIN ENROLMENT E " 
                                "ON S.STUDENTID=E.STUDENTID ",  cnx) 
    print(results) 
    cnx.close()   
fun03()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 6     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 7     JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# 8       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 9        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 10  KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# ...

# %%
import mysql.connector 
import pandas as pd 
import matplotlib.pyplot as plt 
def fun04(): 
    cnx = mysql.connector.connect(user='root', 
                              password='Student123@', 
                              host='localhost', 
                              database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
                                "FROM STUDENT S JOIN ENROLMENT E " 
                                "USING (STUDENTID) ",  cnx) 
    print(results) 
    cnx.close()       
fun04()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 6     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 7     JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# 8       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 9        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 10  KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# ...

# %%
import mysql.connector 
import pandas as pd 
import matplotlib.pyplot as plt 
def fun05(): 
    cnx = mysql.connector.connect(user='root', 
                              password='Student123@', 
                              host='localhost', 
                              database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
                                "FROM STUDENT S INNER JOIN ENROLMENT E " 
                                "ON S.STUDENTID=E.STUDENTID ",  cnx) 
    print(results) 
    cnx.close()       
fun05()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 6     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 7     JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# 8       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 9        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 10  KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# ...

# %%
import mysql.connector 
import pandas as pd 
import matplotlib.pyplot as plt 
def fun06(): 
    cnx = mysql.connector.connect(user='root', 
    password='Student123@', 
    host='localhost', 
    database='week4') 
    results = pd.read_sql_query("SELECT  STUDENTNAME, E.* " 
    "FROM STUDENT S LEFT JOIN ENROLMENT E " 
    "ON S.STUDENTID=E.STUDENTID ",  cnx) 
    print(results) 
    cnx.close()       
fun06()
# Out:
#         STUDENTNAME ENROLMENTID SEMESTER  STUDYYEAR STUDENTID UNITCODE
# 0     MICHAEL BEVAN        E001   SPRING       2020      S001   MDS600
# 1     MICHAEL BEVAN        E002   SPRING       2020      S001   MDS601
# 2     MICHAEL BEVAN        E003   WINTER       2019      S001   MDS603
# 3        BRIAN LARA        E004     FALL       2010      S002   MDS604
# 4    VIVAN RICHARDS        E005     FALL       2015      S003   MDS605
# 5    VIVAN RICHARDS        E010     FALL       2017      S003   MDS603
# 6     JAVED MIANDAD        E006   WINTER       2020      S004   MDS606
# 7     JAVED MIANDAD        E011   WINTER       2014      S004   MDS601
# 8       VIRAT KOHLI        E007   SPRING       2000      S005   MDS602
# 9        BABAR AZAM        E008     FALL       2022      S006   MDS600
# 10  KUMAR SANGAKARA        E009   SPRING       2021      S007   MDS604
# ...
